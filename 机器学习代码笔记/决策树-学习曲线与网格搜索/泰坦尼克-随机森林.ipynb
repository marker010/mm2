# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score

# %%
data = pd.read_csv(r"C:\Users\13708\OneDrive\桌面\泰坦尼克号数据\train.csv")
data.head(5)
# Out:
#    Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  Survived
# 0       3    1  22.0      1      0   7.2500       0.0         0
# 1       1    0  38.0      1      0  71.2833       1.0         1
# 2       3    0  26.0      0      0   7.9250       0.0         1
# 3       1    0  35.0      1      0  53.1000       0.0         1
# 4       3    1  35.0      0      0   8.0500       0.0         0

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(missing_values=np.nan,strategy="mean")

# %%
data['Age'] = imputer.fit_transform(data[['Age']])

# %%
data=data.dropna(axis=0)

# %%
x_data = data.loc[:,data.columns!='Survived']
x_data
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 0         3    1  22.000000      1      0   7.2500       0.0
# 1         1    0  38.000000      1      0  71.2833       1.0
# 2         3    0  26.000000      0      0   7.9250       0.0
# 3         1    0  35.000000      1      0  53.1000       0.0
# 4         3    1  35.000000      0      0   8.0500       0.0
# ..      ...  ...        ...    ...    ...      ...       ...
# 886       2    1  27.000000      0      0  13.0000       0.0
# 887       1    0  19.000000      0      0  30.0000       0.0
# 888       3    0  29.699118      1      2  23.4500       0.0
# 889       1    1  26.000000      0      0  30.0000       1.0
# 890       3    1  32.000000      0      0   7.7500       2.0
#
# [889 rows x 7 columns]

# %%
y_data = data['Survived']

# %%
x_train,x_test,y_train,y_test = train_test_split(x_data,y_data,random_state=42)

# %%
rfc = RandomForestClassifier(random_state=42,n_estimators=100,max_depth=10,min_samples_leaf=10)

# %%
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=10, min_samples_leaf=10, random_state=42)

# %%
rfc.score(x_train,y_train)
# Out:
# 0.8498498498498499

# %%
rfc.score(x_test,y_test)
# Out:
# 0.8295964125560538

# %%
x_test2 = pd.read_csv(r"C:\Users\13708\OneDrive\桌面\泰坦尼克号数据\test.csv")

# %%
x_test2['surived']=rfc.predict(x_test2)

# %%
x_test2
# Out:
#      Pclass  Sex   Age  SibSp  Parch      Fare  Embarked  surived
# 0         3    1  34.5      0      0    7.8292         2        0
# 1         3    0  47.0      1      0    7.0000         0        0
# 2         2    1  62.0      0      0    9.6875         2        0
# 3         3    1  27.0      0      0    8.6625         0        0
# 4         3    0  22.0      1      1   12.2875         0        1
# ..      ...  ...   ...    ...    ...       ...       ...      ...
# 413       3    1   NaN      0      0    8.0500         0        0
# 414       1    0  39.0      0      0  108.9000         1        1
# 415       3    1  38.5      0      0    7.2500         0        0
# 416       3    1   NaN      0      0    8.0500         0        0
# 417       3    1   NaN      1      1   22.3583         1        0
#
# [418 rows x 8 columns]

# %%
x_test2.to_csv(r'C:\Users\13708\OneDrive\桌面\泰坦尼克号数据\predict2.csv', index=True)
