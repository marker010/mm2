# %%
import xlrd
import pandas as pd

# %%
data = xlrd.open_workbook("考试成绩.xls")

# %%
sheet1 = data.sheet_by_index(0)  
sheet2 = data.sheet_by_index(1)

# %%
score_row1 = sheet1.col(3)  
score_row1
# Out:
# [text:'考试成绩',
#  text:'87.00',
#  text:'100.00',
#  text:'57.00',
#  text:'69.00',
#  text:'22.00',
#  text:'38.00',
#  text:'86.00',
#  text:'85.00',
#  text:'65.00',
#  text:'24.00',
#  text:'46.00',
#  text:'70.00',
#  text:'61.00',
#  text:'32.00',
#  text:'12.00',
#  text:'42.00',
#  text:'75.00',
#  text:'74.00',
#  text:'95.00',
#  text:'52.00',
#  text:'97.00',
#  text:'58.00',
#  text:'88.00',
#  text:'75.00',
#  text:'47.00',
#  text:'61.00',
#  text:'61.00',
#  text:'81.00',
#  text:'68.00',
#  text:'83.00',
#  text:'53.00',
#  text:'95.00',
#  text:'36.00',
#  text:'67.00',
#  text:'3.00',
#  text:'34.00',
#  text:'94.00',
#  text:'21.00',
#  text:'72.00',
#  text:'81.00',
#  text:'71.00',
#  text:'76.00',
#  text:'86.00',
#  text:'100.00',
#  text:'15.00',
#  text:'88.00',
#  text:'71.00',
#  text:'79.00',
#  text:'78.00',
#  text:'61.00',
#  text:'96.00',
#  text:'63.00',
#  text:'67.00',
#  text:'72.00',
#  text:'73.00',
#  text:'93.00',
#  text:'90.00',
# ...

# %%
score_row2 = sheet2.col(3)  
score_row2
# Out:
# [text:'考试成绩',
#  text:'80.00',
#  text:'89.00',
#  text:'95.00',
#  text:'91.00',
#  text:'88.00',
#  text:'91.00',
#  text:'76.00',
#  text:'76.00',
#  text:'91.00',
#  text:'88.00',
#  text:'85.00',
#  text:'80.00',
#  text:'91.00',
#  text:'86.00',
#  text:'14.00',
#  text:'92.00',
#  text:'65.00',
#  text:'62.00',
#  text:'53.00',
#  text:'62.00',
#  text:'91.00',
#  text:'91.00',
#  text:'68.00',
#  text:'53.00',
#  text:'95.00',
#  text:'64.00',
#  text:'45.00',
#  text:'63.00',
#  text:'79.00',
#  text:'82.00',
#  text:'91.00',
#  text:'82.00',
#  text:'88.00',
#  text:'36.00',
#  text:'88.00',
#  text:'79.00',
#  text:'60.00',
#  text:'87.00',
#  text:'74.00',
#  text:'64.00',
#  number:20.0,
#  text:'97.00',
#  text:'76.00',
#  text:'49.00',
#  text:'74.00',
#  text:'85.00',
#  text:'42.00',
#  text:'82.00',
#  text:'92.00',
#  text:'92.00',
#  text:'64.00',
#  text:'94.00',
#  text:'68.00',
#  text:'62.00',
#  text:'60.00',
#  text:'91.00',
#  text:'68.00',
# ...
